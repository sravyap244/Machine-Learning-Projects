# %% [markdown]
# import pandas as pd
# import numpy as np
# df=pd.read_csv(r"C:\Users\DELL\Documents\ML\jan 23rd 2025 project-1\housing_price_dataset.csv")

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %% [markdown]
# #### Problem Type is Regression Problem

# %% [markdown]
# ### 1.Business and Data Undersanding

# %%
df.shape
# Out:
# (50000, 6)

# %%
df.memory_usage().sum()
# Out:
# 2400132

# %% [markdown]
# * SquareFeet- Area Occupied by the house - > Numerical column  - 500-5000 (min and max value)
# * Bedrooms-number of bedrooms in the house- >Numerical column	- 1-5
# * Bathrooms-number of bathrooms in the house -> Numerical column - 1-5
# * Neighborhood-where the house is built-> Categorical column
# * YearBuilt-in which year it is built-> Numerical column - 1990-2025
# * Price-the price of the house(output column) -> Numerical column->continous data->regression model

# %% [markdown]
# ### 2. Data Preperation

# %%
## EDA

# %%
df.isnull().sum() #Missing values
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df.duplicated().sum() #duplicates
# Out:
# 0

# %%
#outliers
df['SquareFeet'].min(),df['SquareFeet'].max()
# Out:
# (1000, 2999)

# %%
df['Bathrooms'].min(),df['Bathrooms'].max()
# Out:
# (1, 3)

# %%
df['YearBuilt'].min(),df['YearBuilt'].max()
# Out:
# (1950, 2021)

# %%
df['Price'].min(),df['Price'].max()
# Out:
# (-36588.16539749279, 492195.2599720151)

# %% [markdown]
# ## data cleaning

# %%
df['Price']=np.abs(df['Price'])

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %% [markdown]
# * no missisng values
# * no duplicates
# * outliers are treated

# %%
df['Neighborhood'].unique()
# Out:
# array(['Rural', 'Suburb', 'Urban'], dtype=object)

# %%
df['Neighborhood']=df['Neighborhood'].map({'Rural':0,'Suburb':1,'Urban':2})

# %%
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt          Price
# 0            2126         4          1             0       1969  215355.283618
# 1            2459         3          2             0       1980  195014.221626
# 2            1860         2          1             1       1970  306891.012076
# 3            2294         2          1             2       1996  206786.787153
# 4            2130         5          2             1       2001  272436.239065
# ...           ...       ...        ...           ...        ...            ...
# 49995        1282         5          3             0       1975  100080.865895
# 49996        2854         2          2             1       1988  374507.656727
# 49997        2979         5          3             1       1962  384110.555590
# 49998        2596         5          2             0       1984  380512.685957
# 49999        1572         5          3             0       2011  221618.583218
#
# ...

# %%
### Feature Engineering

# %% [markdown]
# ### 3.Model Building

# %%
X=df.drop('Price',axis=1) #input data
y=df['Price'] #output data/Target column

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23)

# %% [markdown]
# ### KNN Algorithm

# %%
# Loading the algorithm
from sklearn.neighbors import KNeighborsRegressor  
knn=KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ### linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# #### 4.Model Evaluation

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred=knn.predict(X_test)
mean_squared_error(y_pred,y_test)
# Out:
# 2939617716.996368

# %%
y_pred=lr.predict(X_test)  #this is giving less error compared to knn, decision tree algorithms
mean_squared_error(y_pred,y_test)
# Out:
# 2437868887.959436

# %%
y_pred=dt.predict(X_test)
mean_squared_error(y_pred,y_test)
# Out:
# 5241844621.693984

# %% [markdown]
# ### 5.model deployment

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
import pickle

# %%
with open('housepricepred.pkl','wb') as file:
    pickle.dump(lr,file)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Documents\\pract'
